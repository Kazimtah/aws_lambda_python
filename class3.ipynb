# %%
class User:
    def __init__(self, username, email):
        self.username = username
        self.email = email
        
    def info(self):
        print(f"Username: {self.username} and Email: {self.email}")

        
first_user = User("a", "a@gmail.com")
print(first_user.info())
print(first_user)
# Out:
# Username: a and Email: a@gmail.com
# None
# <__main__.User object at 0x7f89dbcab908>
