# %%
print("Hello World")
# Out:
# Hello World

# %%
phone_count = 9  # integer
phone_width_inches = 2.254 # float
phone_height_inches = 6.25 # float
phone_make = "Example" # string
phone_option = bool # bolean
phone_condition = None #None type
phone_name = printf("{} is {} square marchinngi")

# %%
number_one = 7
number_two = 5

if number_one > number_two:
    print(f"The {number_one} is greater than {number_two}")
elif number_two >number_one:
    print(f"the {number_two} is greater than the {number_one}")
    
else:
    print(f"the {number_one} is equal {number_two}")
# Out:
# The 7 is greater than 5

# %%
message_one = "hello"
message_two = "hi"
if message_one != message_two:
    print("the message differ")
    
else:
    print("the message is the same")
# Out:
# the message differ

# %%
def say_hello():
    print("Hello, world")
    
say_hello()
say_hello()
say_hello()
# Out:
# Hello, world
# Hello, world
# Hello, world

# %%
def square_number(numbers):
    return numbers**2 

squared_number = print(square_number(2))
# Out:
# 4

# %%
def comparing_string(string_one, string_two):
    if string_one == string_two:
        return True 
    else:
        return False
    
compared_string = comparing_string("helo", "hello")
print(compared_string)
# Out:
# False
